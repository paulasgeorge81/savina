# %% [markdown]
# Import Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the Data

# %%
parent_dir = '../../data/fib/'

df = pd.read_csv(f'{parent_dir}/aggregate_energy_results.csv')

# %% [markdown]
# Preview the Data

# %%
print("Data:")
print(df.shape)
df.head(10)
# Out:
# Data:
# (2, 4)
#     N  Iterations  Erlang Energy Consumption(J)  Scala Energy Consumption(J)
# 0  25          15                    134.302694                   504.002313
# 1  30          15                   1429.540641                  5784.979080

# %% [markdown]
# Visualize the Data

# %%
# Set the plot style
sns.set_theme(style="whitegrid", palette="muted")

# Plotting the energy consumption
plt.figure(figsize=(10, 6))

# Plot Erlang and Scala energy consumption
sns.lineplot(x="N", y="Erlang Energy Consumption(J)", data=df, marker='o', label="Erlang Energy Consumption (J)", color="blue")
sns.lineplot(x="N", y="Scala Energy Consumption(J)", data=df, marker='o', label="Scala Energy Consumption (J)", color="green")

# Adding labels and title
plt.xlabel("N (Index)")
plt.ylabel("Energy Consumption (Joules)")
plt.title(" Erlang vs Scala Fibonacci Benchmark Energy Consumption")
plt.xscale("log")
plt.yscale("log")

# Display legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()
